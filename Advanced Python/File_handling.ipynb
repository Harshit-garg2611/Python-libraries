# %% [markdown]
# ## File Handling in Python
# - File handling is the process of creating, reading, writing, and managing files in a program
# - Makes system robust, secure, maintainable

# %%
# Open, read & write 

# We have to open a file before reading and writing 
# f = open('file','mode')

file = open('simple.txt')   # by default mode read

# RECOMMENDED : f = open('path/name.txt','mode') 


# after opening a 
content = file.read()
print(content)
# Out:
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
# Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
#
# This sample TXT file is provided by Sample-Files.com. Visit us for more sample files and resources.
